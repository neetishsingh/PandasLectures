# %% [markdown]
# <h2>Introduction to Pandas | Lecture 1 | Neetish Singh</h2>

# %% [markdown]
# <h6>Step 1:Import pandas library to your project and you can rename it if you want</h6>

# %%
import pandas as pd

# %% [markdown]
# <h3 style='color:red'>Dataframe:</h3><h4> Dateframe is a datastructure used to store data in form of tables and to facilitate the operations and functions</h4>

# %% [markdown]
# <h6>Step 2: import data from external sources(i.e csv,excel,Json,Html) to our dataframe.</h6>

# %%
df=pd.read_csv('Downloads/heart.csv')

# %% [markdown]
# <h6>We can display the imported data either from top or bottom or from particular selection<h6>

# %% [markdown]
# <h5>1.From Top</h5>

# %%
df.head()      #df.head(no_of_rows)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %% [markdown]
# <h5>2.From Bottom</h5>

# %%
df.tail()      #df.tail(no_of_rows)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0

# %% [markdown]
# <h5>3.From Particular Selection</h5>

# %%
df[3:123]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# 7     44    1   1       120   263    0        1      173      0      0.0
# 8     52    1   2       172   199    1        1      162      0      0.5
# 9     57    1   2       150   168    0        1      174      0      1.6
# 10    54    1   0       140   239    0        1      160      0      1.2
# 11    48    0   2       130   275    0        1      139      0      0.2
# 12    49    1   1       130   266    0        1      171      0      0.6
# 13    64    1   3       110   211    0        0      144      1      1.8
# 14    58    0   3       150   283    1        0      162      0      1.0
# ...

# %%
df.age #df['age'] both are same
# Out:
# 0      63
# 1      37
# 2      41
# 3      56
# 4      57
# 5      57
# 6      56
# 7      44
# 8      52
# 9      57
# 10     54
# 11     48
# 12     49
# 13     64
# 14     58
# 15     50
# 16     58
# 17     66
# 18     43
# 19     69
# 20     59
# 21     44
# 22     42
# 23     61
# 24     40
# 25     71
# 26     59
# 27     51
# 28     65
# 29     53
#        ..
# 273    58
# 274    47
# 275    52
# 276    58
# 277    57
# 278    58
# 279    61
# 280    42
# 281    52
# 282    59
# 283    40
# 284    61
# 285    46
# 286    59
# 287    57
# 288    57
# 289    55
# 290    61
# 291    58
# 292    58
# 293    67
# 294    44
# 295    63
# 296    63
# 297    59
# 298    57
# 299    45
# 300    68
# 301    57
# 302    57
# Name: age, Length: 303, dtype: int64

# %%
df[df.age>df.age.mean()].sex #can execute conditional things
# Out:
# 0      1
# 3      1
# 4      0
# 5      1
# 6      0
# 9      1
# 13     1
# 14     0
# 16     0
# 17     0
# 19     0
# 20     1
# 23     1
# 25     0
# 26     1
# 28     0
# 31     1
# 38     0
# 39     0
# 51     1
# 52     1
# 54     0
# 59     0
# 60     0
# 64     1
# 69     0
# 75     0
# 77     1
# 79     1
# 82     0
#       ..
# 258    0
# 260    0
# 263    0
# 265    1
# 266    0
# 269    1
# 271    1
# 272    1
# 273    1
# 276    1
# 277    1
# 278    0
# 279    1
# 282    1
# 284    1
# 286    1
# 287    1
# 288    1
# 289    0
# 290    1
# 291    1
# 292    0
# 293    1
# 295    1
# 296    0
# 297    1
# 298    0
# 300    1
# 301    1
# 302    0
# Name: sex, Length: 159, dtype: int64

# %%
df.index
# Out:
# RangeIndex(start=0, stop=303, step=1)

# %%
df[['age','sex']]
# Out:
#      age  sex
# 0     63    1
# 1     37    1
# 2     41    0
# 3     56    1
# 4     57    0
# 5     57    1
# 6     56    0
# 7     44    1
# 8     52    1
# 9     57    1
# 10    54    1
# 11    48    0
# 12    49    1
# 13    64    1
# 14    58    0
# 15    50    0
# 16    58    0
# 17    66    0
# 18    43    1
# 19    69    0
# 20    59    1
# 21    44    1
# 22    42    1
# 23    61    1
# 24    40    1
# 25    71    0
# 26    59    1
# 27    51    1
# 28    65    0
# 29    53    1
# ..   ...  ...
# 273   58    1
# 274   47    1
# 275   52    1
# 276   58    1
# 277   57    1
# 278   58    0
# 279   61    1
# 280   42    1
# 281   52    1
# 282   59    1
# 283   40    1
# 284   61    1
# 285   46    1
# 286   59    1
# 287   57    1
# 288   57    1
# 289   55    0
# 290   61    1
# 291   58    1
# 292   58    0
# 293   67    1
# 294   44    1
# 295   63    1
# 296   63    0
# 297   59    1
# 298   57    0
# 299   45    1
# 300   68    1
# 301   57    1
# 302   57    0
#
# ...

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df.columns[2]
# Out:
# 'cp'

# %%
df[df.columns[1]]
# Out:
# 0      1
# 1      1
# 2      0
# 3      1
# 4      0
# 5      1
# 6      0
# 7      1
# 8      1
# 9      1
# 10     1
# 11     0
# 12     1
# 13     1
# 14     0
# 15     0
# 16     0
# 17     0
# 18     1
# 19     0
# 20     1
# 21     1
# 22     1
# 23     1
# 24     1
# 25     0
# 26     1
# 27     1
# 28     0
# 29     1
#       ..
# 273    1
# 274    1
# 275    1
# 276    1
# 277    1
# 278    0
# 279    1
# 280    1
# 281    1
# 282    1
# 283    1
# 284    1
# 285    1
# 286    1
# 287    1
# 288    1
# 289    0
# 290    1
# 291    1
# 292    0
# 293    1
# 294    1
# 295    1
# 296    0
# 297    1
# 298    0
# 299    1
# 300    1
# 301    1
# 302    0
# Name: sex, Length: 303, dtype: int64

# %%
df.index
df
# Out:
#      sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# age
# 63     1   3       145   233    1        0      150      0      2.3      0
# 37     1   2       130   250    0        1      187      0      3.5      0
# 41     0   1       130   204    0        0      172      0      1.4      2
# 56     1   1       120   236    0        1      178      0      0.8      2
# 57     0   0       120   354    0        1      163      1      0.6      2
# 57     1   0       140   192    0        1      148      0      0.4      1
# 56     0   1       140   294    0        0      153      0      1.3      1
# 44     1   1       120   263    0        1      173      0      0.0      2
# 52     1   2       172   199    1        1      162      0      0.5      2
# 57     1   2       150   168    0        1      174      0      1.6      2
# 54     1   0       140   239    0        1      160      0      1.2      2
# ...

# %%
df.reset_index(inplace=True)

# %%
df.set_index('age',inplace=True)

# %%
df.sex.mean()
# Out:
# 0.6831683168316832
